# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot  as plt 
import seaborn as sns 
# %matplotlib inline

# %%
customer_df= pd.read_csv('D:\Data Analysis With Python\GDSC_ML_Task\data\WA_Fn-UseC_-Telco-Customer-Churn.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Sian\AppData\Local\Temp\ipykernel_2360\2199856856.py:1: SyntaxWarning: invalid escape sequence '\D'
#   customer_df= pd.read_csv('D:\Data Analysis With Python\GDSC_ML_Task\data\WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
customer_df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
customer_df.shape
# Out:
# (7043, 21)

# %%
customer_df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
customer_df.columns.unique()
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
for items in customer_df.columns:
    if(items != 'customerID'):
        print(f"Unique Values in column {items}  is : {customer_df[items].unique()}")
# Out:
# Unique Values in column gender  is : ['Female' 'Male']
# Unique Values in column SeniorCitizen  is : [0 1]
# Unique Values in column Partner  is : ['Yes' 'No']
# Unique Values in column Dependents  is : ['No' 'Yes']
# Unique Values in column tenure  is : [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# Unique Values in column PhoneService  is : ['No' 'Yes']
# Unique Values in column MultipleLines  is : ['No phone service' 'No' 'Yes']
# Unique Values in column InternetService  is : ['DSL' 'Fiber optic' 'No']
# Unique Values in column OnlineSecurity  is : ['No' 'Yes' 'No internet service']
# Unique Values in column OnlineBackup  is : ['Yes' 'No' 'No internet service']
# Unique Values in column DeviceProtection  is : ['No' 'Yes' 'No internet service']
# ...
